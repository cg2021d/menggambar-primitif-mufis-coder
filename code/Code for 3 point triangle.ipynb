# %%
lis = [[826, 627],
[795, 626],
[765, 631],
[730, 627],
[702, 625],
[673, 615],
[645, 602],
[626, 586],
[604, 569],
[593, 552],
[587, 535],
[595, 520],
[616, 508],
[639, 502],
[663, 501],
[691, 505],
[714, 509],
[740, 515],
[765, 521],
[794, 523],
[819, 528],
[848, 536],
[873, 554],
[891, 577],
[896, 595],
[895, 617],
[889, 642],
[874, 664],
[862, 677],
[846, 686],
[825, 689],
[801, 695],
[772, 701],
[744, 701],
[716, 701],
[687, 696],
[661, 687],
[636, 680],
[614, 670],
[595, 653],
[573, 634],
[562, 615],
[558, 598],
[554, 569],
[560, 551],
[576, 533],
[591, 518],
[616, 502],
[640, 493],
[665, 485],
[690, 483],
[717, 482],
[741, 481],
[767, 485],
[795, 487],
[820, 490],
[843, 493],
[867, 504],
[887, 514],
[906, 526],
[926, 542],
[925, 563],
[918, 584],
[909, 595],
[894, 606],
[876, 612],
[853, 618],
[818, 617]]

# %%
lis2 = [[747, 683],
[719, 683],
[681, 671],
[652, 664],
[622, 650],
[593, 633],
[576, 615],
[565, 592],
[574, 558],
[601, 564],
[626, 568],
[641, 567],
[664, 566],
[690, 566],
[715, 567],
[741, 568],
[767, 569],
[793, 567],
[813, 568],
[832, 574],
[848, 583],
[864, 594],
[875, 608],
[899, 628],
[914, 663],
[909, 687],
[890, 712],
[870, 730],
[846, 746],
[817, 755],
[786, 762],
[746, 760],
[715, 757],
[686, 751],
[655, 744],
[629, 728],
[603, 718],
[588, 702],
[557, 680],
[541, 626],
[545, 608],
[550, 589],
[568, 567],
[589, 553],
[611, 539],
[633, 531],
[649, 522],
[676, 517],
[698, 517],
[720, 513],
[740, 516],
[766, 517],
[790, 520],
[814, 525],
[830, 526],
[865, 539],
[878, 547],
[908, 572],
[942, 605],
[935, 628],
[915, 660],
[895, 671],
[873, 674],
[848, 682],
[815, 684],
[783, 686],
[750, 683]]

# %%
len(lis2)
# Out:
# 67

# %%
all = []
for x, y in zip(lis, lis2):
  # print('{}, {}, {}, {}, {},'.format(((x[0]-900)/1000), ((1000-x[1])/1000), 1.0, 0.0, 0.0))
  all.append(x)
  all.append(y)

# %%
all
# Out:
# [[826, 627],
#  [747, 683],
#  [795, 626],
#  [719, 683],
#  [765, 631],
#  [681, 671],
#  [730, 627],
#  [652, 664],
#  [702, 625],
#  [622, 650],
#  [673, 615],
#  [593, 633],
#  [645, 602],
#  [576, 615],
#  [626, 586],
#  [565, 592],
#  [604, 569],
#  [574, 558],
#  [593, 552],
#  [601, 564],
#  [587, 535],
#  [626, 568],
#  [595, 520],
#  [641, 567],
#  [616, 508],
#  [664, 566],
#  [639, 502],
#  [690, 566],
#  [663, 501],
#  [715, 567],
#  [691, 505],
#  [741, 568],
#  [714, 509],
#  [767, 569],
#  [740, 515],
#  [793, 567],
#  [765, 521],
#  [813, 568],
#  [794, 523],
#  [832, 574],
#  [819, 528],
#  [848, 583],
#  [848, 536],
#  [864, 594],
#  [873, 554],
#  [875, 608],
#  [891, 577],
#  [899, 628],
#  [896, 595],
#  [914, 663],
#  [895, 617],
#  [909, 687],
#  [889, 642],
#  [890, 712],
#  [874, 664],
#  [870, 730],
#  [862, 677],
#  [846, 746],
#  [846, 686],
#  [817, 755],
#  [825, 689],
#  [786, 762],
#  [801, 695],
#  [746, 760],
#  [772, 701],
#  [715, 757],
# ...

# %%
ll = []
bagi = 800
ypos = 600
xpos = 400
for i in range(0,len(all)-2):
  temp = all[i:i+3]
  ll.append(temp)
  cor1 = temp[0]
  cor2 = temp[1]
  cor3 = temp[2]
  print('{}, {}, {}, {}, {},'.format(((cor1[0]-xpos)/bagi), ((ypos-cor1[1])/bagi), 1.0, 0.0, 0.0))
  print('{}, {}, {}, {}, {},'.format(((cor2[0]-xpos)/bagi), ((ypos-cor2[1])/bagi), 1.0, 0.0, 0.0))
  print('{}, {}, {}, {}, {},'.format(((cor3[0]-xpos)/bagi), ((ypos-cor3[1])/bagi), 1.0, 0.0, 0.0))
  print('')
# Out:
# 0.5325, -0.03375, 1.0, 0.0, 0.0,
# 0.43375, -0.10375, 1.0, 0.0, 0.0,
# 0.49375, -0.0325, 1.0, 0.0, 0.0,
#
# 0.43375, -0.10375, 1.0, 0.0, 0.0,
# 0.49375, -0.0325, 1.0, 0.0, 0.0,
# 0.39875, -0.10375, 1.0, 0.0, 0.0,
#
# 0.49375, -0.0325, 1.0, 0.0, 0.0,
# 0.39875, -0.10375, 1.0, 0.0, 0.0,
# 0.45625, -0.03875, 1.0, 0.0, 0.0,
#
# 0.39875, -0.10375, 1.0, 0.0, 0.0,
# 0.45625, -0.03875, 1.0, 0.0, 0.0,
# 0.35125, -0.08875, 1.0, 0.0, 0.0,
#
# 0.45625, -0.03875, 1.0, 0.0, 0.0,
# 0.35125, -0.08875, 1.0, 0.0, 0.0,
# 0.4125, -0.03375, 1.0, 0.0, 0.0,
#
# 0.35125, -0.08875, 1.0, 0.0, 0.0,
# 0.4125, -0.03375, 1.0, 0.0, 0.0,
# 0.315, -0.08, 1.0, 0.0, 0.0,
#
# 0.4125, -0.03375, 1.0, 0.0, 0.0,
# 0.315, -0.08, 1.0, 0.0, 0.0,
# 0.3775, -0.03125, 1.0, 0.0, 0.0,
#
# 0.315, -0.08, 1.0, 0.0, 0.0,
# 0.3775, -0.03125, 1.0, 0.0, 0.0,
# 0.2775, -0.0625, 1.0, 0.0, 0.0,
#
# 0.3775, -0.03125, 1.0, 0.0, 0.0,
# 0.2775, -0.0625, 1.0, 0.0, 0.0,
# 0.34125, -0.01875, 1.0, 0.0, 0.0,
#
# 0.2775, -0.0625, 1.0, 0.0, 0.0,
# ...

# %%
len(ll)
# Out:
# 132

# %%
lsnew = [
[748, 633],
[752, 680],
[727, 649],
[718, 688],
[700, 655],
[690, 690],


[681, 639],
[652, 677],
[668, 630],
[637, 662],
[668, 625],
[628, 654],
[669, 620],
[617, 640],
[670, 612],
[615, 627],
[669, 603],
[613, 608],
[673, 592],
[617, 588],
[674, 575],
[619, 574],
[677, 550],
[627, 550],
[679, 531],
[634, 536],
[683, 509],
[644, 511],
[688, 493],
[659, 489],
[688, 494],



[670, 478],

[686, 519], #ASLI
# [688, 520],

[670, 478],
[700, 520],
[698, 467],
[718, 513],
[722, 463],
[727, 512],
[748, 467],
[744, 515],
[767, 475],
[764, 519],
[782, 482],
[779, 527],
[834, 519],
[831, 534],
[853, 548],
[830, 558],
[859, 572],
[827, 580],
[858, 592],




[819, 599],
[855, 616],
[817, 620],
[845, 642],
[811, 639],
[835, 669],
[800, 657],
[823, 689],
[792, 675],
[808, 704],
[773, 684],
[791, 727],
[753, 696],
[765, 740],
[735, 708],
[717, 752],
[687, 712],
[679, 756],
[666, 709],
[629, 735],
[636, 697],
[605, 715],
[621, 660],
[586, 680],
[612, 642],
[580, 656],
[610, 624],
[574, 629],
[608, 602],
[576, 607],
[613, 587],
[579, 586],
[617, 574],
[578, 565],
[618, 559],
[585, 543],
[625, 541],
[590, 525],
[631, 524],
[603, 503],
[640, 508],
[613, 487],
[649, 493],
[630, 468],
[661, 480],
[645, 450],
[677, 467],
[664, 441],
[697, 456],
[688, 430],
[713, 449],
[711, 425],
[736, 457],
[739, 422],
[750, 458],
[757, 425],
[761, 464],
[777, 433],
[770, 474],
[792, 443],
[775, 478],
[802, 460],
[782, 489],
[809, 475],
[791, 513],
[813, 493],
[794, 531],
[818, 515],
[791, 543],
[819, 536],
[791, 562],
[822, 577],
[782, 582],
[816, 604],
[776, 596],
[796, 634],
[765, 610],
[796, 646],
[758, 619],
[782, 658],
[740, 632],
[745, 677],
[748, 633],


]

# %%
ll = []
bagi = 800
ypos = 580
xpos = 1180
for i in range(0,len(lsnew)-2):
  temp = lsnew[i:i+3]
  ll.append(temp)
  cor1 = temp[0]
  cor2 = temp[1]
  cor3 = temp[2]
  print('{}, {}, {}, {}, {},'.format(((cor1[0]-xpos)/bagi), ((ypos-cor1[1])/bagi), 1.0, 0.0, 0.0))
  print('{}, {}, {}, {}, {},'.format(((cor2[0]-xpos)/bagi), ((ypos-cor2[1])/bagi), 1.0, 0.0, 0.0))
  print('{}, {}, {}, {}, {},'.format(((cor3[0]-xpos)/bagi), ((ypos-cor3[1])/bagi), 1.0, 0.0, 0.0))
  print('')
# Out:
# -0.54, -0.06625, 1.0, 0.0, 0.0,
# -0.535, -0.125, 1.0, 0.0, 0.0,
# -0.56625, -0.08625, 1.0, 0.0, 0.0,
#
# -0.535, -0.125, 1.0, 0.0, 0.0,
# -0.56625, -0.08625, 1.0, 0.0, 0.0,
# -0.5775, -0.135, 1.0, 0.0, 0.0,
#
# -0.56625, -0.08625, 1.0, 0.0, 0.0,
# -0.5775, -0.135, 1.0, 0.0, 0.0,
# -0.6, -0.09375, 1.0, 0.0, 0.0,
#
# -0.5775, -0.135, 1.0, 0.0, 0.0,
# -0.6, -0.09375, 1.0, 0.0, 0.0,
# -0.6125, -0.1375, 1.0, 0.0, 0.0,
#
# -0.6, -0.09375, 1.0, 0.0, 0.0,
# -0.6125, -0.1375, 1.0, 0.0, 0.0,
# -0.62375, -0.07375, 1.0, 0.0, 0.0,
#
# -0.6125, -0.1375, 1.0, 0.0, 0.0,
# -0.62375, -0.07375, 1.0, 0.0, 0.0,
# -0.66, -0.12125, 1.0, 0.0, 0.0,
#
# -0.62375, -0.07375, 1.0, 0.0, 0.0,
# -0.66, -0.12125, 1.0, 0.0, 0.0,
# -0.64, -0.0625, 1.0, 0.0, 0.0,
#
# -0.66, -0.12125, 1.0, 0.0, 0.0,
# -0.64, -0.0625, 1.0, 0.0, 0.0,
# -0.67875, -0.1025, 1.0, 0.0, 0.0,
#
# -0.64, -0.0625, 1.0, 0.0, 0.0,
# -0.67875, -0.1025, 1.0, 0.0, 0.0,
# -0.64, -0.05625, 1.0, 0.0, 0.0,
#
# -0.67875, -0.1025, 1.0, 0.0, 0.0,
# ...

# %%
len(ll)
# Out:
# 133
